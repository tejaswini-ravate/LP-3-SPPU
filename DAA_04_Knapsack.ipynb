# %%
def knapsack(val,wt,W):
    n = len(val)
    dp = [[0 for _ in range (W+1)]for _ in range (n+1)]
    for i in range(1,n+1):
        for j in range(1,W+1):
            if wt[i-1] > j:
                dp[i][j] = dp[i-1][j]
            else:
                dp[i][j] = max(dp[i-1][j],val[i-1]+dp[i-1][j-wt[i-1]])
    return dp[n][W]

# %%
def main():
    while True:
        val = list(map(int,input("Enter values:").split()))
        wt = list(map(int,input("Enter weights:").split()))
        W = int(input("Enter weight:"))
        print(f"MAximum value:{knapsack(val,wt,W)}")
        ans = str(input("Enter y/n to continue:"))
        if(ans=='n'):
            break

    print()

# %%
if __name__ == "__main__":
    main()
# Out:
# Enter values: 2 3 4 5 6
# Enter weights: 30 40 50 60  70
# Enter weight: 70
# MAximum value:6
# Enter y/n to continue: n
